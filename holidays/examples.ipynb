# %%
from fyers_holidays import get_holidays, isHoliday

# %%
get_holidays()
# Out:
# [{'holiday_date': '26-01-2023',
#   'holiday_day': 'Thursday',
#   'holiday_name': 'Republic Day',
#   'Equity': True,
#   'Currency': True,
#   'F&O': True,
#   'Clearing': True,
#   'Commodity Morning': False,
#   'Commodity': True},
#  {'holiday_date': '07-03-2023',
#   'holiday_day': 'Tuesday',
#   'holiday_name': 'Holi',
#   'Equity': True,
#   'Currency': True,
#   'F&O': True,
#   'Clearing': True,
#   'Commodity Morning': True,
#   'Commodity': False},
#  {'holiday_date': '22-03-2023',
#   'holiday_day': 'Wednesday',
#   'holiday_name': 'Gudipadwa',
#   'Equity': False,
#   'Currency': True,
#   'F&O': False,
#   'Clearing': True,
#   'Commodity Morning': False,
#   'Commodity': False},
#  {'holiday_date': '30-03-2023',
#   'holiday_day': 'Thursday',
#   'holiday_name': 'Ram Navami',
#   'Equity': True,
#   'Currency': True,
#   'F&O': True,
#   'Clearing': True,
#   'Commodity Morning': True,
#   'Commodity': False},
#  {'holiday_date': '04-04-2023',
# ...

# %%
isHoliday("18-08-2023")
# Out:
# {'Equity': False,
#  'Currency': False,
#  'F&O': False,
#  'Clearing': False,
#  'Commodity Morning': False,
#  'Commodity': False}

# %%
isHoliday(date_string="24-10-2023", segment="F&O")
# Out:
# True
